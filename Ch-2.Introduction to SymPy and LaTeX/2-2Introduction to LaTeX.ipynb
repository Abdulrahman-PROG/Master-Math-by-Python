# %% [markdown]
# ![image.png](attachment:image.png)

# %%
print('4 + 3 = 7')
# Out:
# 4 + 3 = 7

# %%
from IPython.display import display,Math

display(Math('4 + 3 = 7'))
# Out:
# $\displaystyle 4 + 3 = 7$

# %%
display(Math('\\sigma'))
# Out:
# $\displaystyle \sigma$

# %%
display(Math('\\mu '))
# Out:
# $\displaystyle \mu $

# %%
display(Math('x_m'))
# Out:
# $\displaystyle x_m$

# %%
display(Math('x_mm'))
# Out:
# $\displaystyle x_mm$

# %%
display(Math('x_m_m'))
# Out:
# $\displaystyle x_m_m$

# %%
display(Math('x_{mm}'))
# Out:
# $\displaystyle x_{mm}$

# %%
display(Math('x^m'))
# Out:
# $\displaystyle x^m$

# %%
display(Math('x^{mm-4}'))
# Out:
# $\displaystyle x^{mm-4}$

# %%
display(Math('\\sqrt{4+5}'))
# Out:
# $\displaystyle \sqrt{4+5}$

# %%
display(Math('\\sqrt{x}\\sqrt{x}'))
# Out:
# $\displaystyle \sqrt{x}\sqrt{x}$

# %% [markdown]
# $$\sqrt{x}\sqrt{x}$$

# %% [markdown]
# $$\text{latex text here ex: } \frac{1+x}{2^x - 1^{3-7y}}$$
