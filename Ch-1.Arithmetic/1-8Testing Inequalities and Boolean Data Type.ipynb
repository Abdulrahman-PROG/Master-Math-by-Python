# %%
4 > 5
# Out:
# False

# %%
4 < 5
# Out:
# True

# %%
a  = 10 > 3*3

# %%
a
# Out:
# True

# %%
print(type(a))
# Out:
# <class 'bool'>

# %%
 4 >= 2+2
# Out:
# True

# %%
 4 >= 2+2+1
# Out:
# False

# %%
 4 <= 2+2+1
# Out:
# True

# %%
4 == 4
# Out:
# True

# %%
a = 4 == 4

# %%
a
# Out:
# True

# %% [markdown]
# --------------------------------------------------------------

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
x = 2
print(4*x + 3 > 17 - x**2 )
x = 3 
print(4*x + 3 > 17 - x**2 )
x = 4
print(4*x + 3 > 17 - x**2 )
# Out:
# False
# True
# True

# %% [markdown]
# ---------------------

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
x = 2
print(8*x - 2 <= -3*x + 42 )
x = 3 
print(8*x - 2 <= -3*x + 42 )
x = 4
print(8*x - 2 <= -3*x + 42 )
# Out:
# True
# True
# True
