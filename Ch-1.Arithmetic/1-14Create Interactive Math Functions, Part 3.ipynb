# %% [markdown]
# ![image.png](attachment:image.png)

# %%
from numpy import random


def guessTheNumber():
    
    num2guess = random.randint(1,101)
    
    userguess =int(input('Guess a number between 1 and 100'))
        
    while num2guess != userguess:
        if num2guess > userguess:
            print('Guess lower')
            
        elif num2guess < userguess:
            print('Guess Higher')
            
        userguess =int(input('Guess again: '))
            
    print(f'Got it! The right number was {num2guess} and your final guess was {userguess}')

# %%
guessTheNumber()
# Out:
# Guess a number between 1 and 1004
# Guess lower
# Guess again: 6
# Guess lower
# Guess again: 9
# Guess lower
# Guess again: 44
# Guess Higher
# Guess again: 33
# Guess Higher
# Guess again: 22
# Guess Higher
# Guess again: 15
# Guess lower
# Guess again: 16
# Guess lower
# Guess again: 17
# Guess lower
# Guess again: 18
# Guess lower
# Guess again: 19
# Got it! The right number was 19 and your final guess was 19
